# %% [markdown]
# # Project 2
# ## Team B, CA Beaches

# %%
# set environment
from datetime import date
import pandas as pd
import json
import requests

# %%
from sqlalchemy import create_engine, insert
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
#from config import password

# %%
# define our base URL
base_url = "https://admin.beachreportcard.org/api/locations"

# %%
# read JSON data from web
r = requests.get(base_url)

# create empty list of column names
title_list = []

# loop through water quality data
for row in r.json():
    # grab all the keys from the source dict
    key_list = row["_source"].keys()
    
    # if we find a key we haven't seen
    # before, add it to out list
    for key in key_list:
        if key not in title_list:
            title_list.append(key)
            
#print(title_list)

# %%
# create empty beach dict
beach_data = {}

# loop through list of all titles found across all beaches
# and add an empty array to the beach data for each
for title in title_list:
    # need to break up the geo coordinates
    if title == "geo":
        beach_data["latitude"] = []
        beach_data["longitude"] = []
    else:
        beach_data[title] = []

#print(beach_data)

# loop through all the beaches we scraped
for beach in r.json():
    # we only want cali data
    if beach["_source"]["state"] == "CA":
     
        for title in title_list:
            if title == "alerts":
                # grab current Alerts instead of _source.alerts
                if "currentAlert" in beach:
                    beach_data["alerts"].append(beach["currentAlert"])
                else:
                    beach_data["alerts"].append("")

            # check for data in associated with this key
            if title in beach["_source"]:
                # skip if alerts, we got it from currentAlert
                if title == "alerts":
                    continue
                    
                if title == "geo":
                    # separate coordinates
                    beach_data["latitude"].append(beach["_source"][title][0])
                    beach_data["longitude"].append(beach["_source"][title][1])
                else:
                    # we have data in this field, add it to our array
                    beach_data[title].append(beach["_source"][title])
            else:
                # no data found for this column name --
                # set to null
                beach_data[title].append("")
        

#print(beach_data)
#print(len(beach_data))

# %%
# dump data into dataframe
beach_df = pd.DataFrame(beach_data)

# %%
# display dataframe
beach_df.head()
# Out:
#      id                                        title         name1  \
# 0  1044                         31502 Victoria Point
# 1    55                  Abalone Cove Shoreline Park  Abalone Cove
# 2   133       Alamitos Bay - 56th Place - on bayside  Alamitos Bay
# 3   608  Alamitos Bay - Division Street and Bayshore  Alamitos Bay
# 4   135                   Alamitos Bay - shore float  Alamitos Bay
#
#                                name2    name3  \
# 0
# 1                     Shoreline Park
# 2                      at 56th Place  bayside
# 3  between Division St. and Bayshore
# 4                        shore float
#
#                                          description notes          comments  \
# 0  Single family residence sewage spill, 100 yard...
# 1  Abalone Cove is an 'open ocean' rocky beach lo...                 abalone
# 2                                                                 alamitos56
# 3                                                           alamitosdivision
# 4                                                              alamitosfloat
#
#   address                 city  ... dry_grade grade_note wet_grade  \
# 0                       Malibu  ...        ns                   ns
# 1          Rancho Palos Verdes  ...        A+                   A+
# 2                   Long Beach  ...         C                   ns
# 3                   Long Beach  ...        ns
# 4                   Long Beach  ...        A+                    B
#
#               grade_created nowcast_pass_flag              nowcast_date  \
# 0  2015-05-04T00:00:00.000Z                    2018-07-04T05:00:00.000Z
# 1  2021-04-02T00:00:00.000Z                    2018-05-07T05:00:00.000Z
# 2  2020-04-10T00:00:00.000Z
# 3  2019-03-15T00:00:00.000Z
# 4  2021-04-02T00:00:00.000Z                    2020-08-26T05:00:00.000Z
#
#    annual_summer_dry annual_year_wet annual_winter_dry annual_year
# 0
# 1
# 2                  A               D                 A        2018
# 3
# 4                  A               C                A+        2018
#
# [5 rows x 38 columns]

# %%
# pull out columns of value
beach_df = beach_df[["id", "title", "name1", "latitude", "longitude", "address", "city", "state", "zip", "county", "active", "grade_updated","dry_grade", "wet_grade", "annual_summer_dry", "annual_year_wet", "annual_winter_dry", "annual_year", "grade_created", "alerts"]]

# %%
beach_df.head()
# Out:
#      id                                        title         name1  \
# 0  1044                         31502 Victoria Point
# 1    55                  Abalone Cove Shoreline Park  Abalone Cove
# 2   133       Alamitos Bay - 56th Place - on bayside  Alamitos Bay
# 3   608  Alamitos Bay - Division Street and Bayshore  Alamitos Bay
# 4   135                   Alamitos Bay - shore float  Alamitos Bay
#
#              latitude             longitude address                 city  \
# 0  34.035252000000000  -118.861320000000000                       Malibu
# 1  33.741585000000000  -118.379189000000000          Rancho Palos Verdes
# 2  33.751183333000000  -118.125783333000000                   Long Beach
# 3  33.756313000000000  -118.131158000000000                   Long Beach
# 4  33.754166666000000  -118.130950000000000                   Long Beach
#
#   state    zip                        county  active  \
# 0    CA  90265                   Los Angeles   False
# 1    CA  90275  Los Angeles -- LA Sanitation    True
# 2    CA  90803     Los Angeles -- Long Beach    True
# 3    CA  90803     Los Angeles -- Long Beach   False
# 4    CA  90803     Los Angeles -- Long Beach    True
#
#               grade_updated dry_grade wet_grade annual_summer_dry  \
# 0  2018-07-04T12:39:31.100Z        ns        ns
# 1  2021-04-02T00:00:00.000Z        A+        A+
# 2  2020-04-10T00:00:00.000Z         C        ns                 A
# 3  2019-03-15T00:00:00.000Z        ns
# 4  2021-04-02T00:00:00.000Z        A+         B                 A
#
#   annual_year_wet annual_winter_dry annual_year             grade_created  \
# 0                                                2015-05-04T00:00:00.000Z
# 1                                                2021-04-02T00:00:00.000Z
# 2               D                 A        2018  2020-04-10T00:00:00.000Z
# 3                                                2019-03-15T00:00:00.000Z
# 4               C                A+        2018  2021-04-02T00:00:00.000Z
#
#   alerts
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
# write dataframe to a CSV file
beach_df.to_csv("data/grade_info.csv")
