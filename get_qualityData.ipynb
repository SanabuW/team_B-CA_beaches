# %% [markdown]
# # Project 2
# ## Team B, CA Beaches

# %%
# set environment
from datetime import date
import pandas as pd
import json
import requests

# %%
from sqlalchemy import create_engine, insert
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
#from config import password

# %%
# define our base URL
base_url = "https://admin.beachreportcard.org/api/locations"

# %%
# read JSON data from web
r = requests.get(base_url)

# create empty list of column names
title_list = []

# loop through water quality data
for row in r.json():
    # grab all the keys from the source dict
    key_list = row["_source"].keys()
    
    # if we find a key we haven't seen
    # before, add it to out list
    for key in key_list:
        if key not in title_list:
            title_list.append(key)
            
#print(title_list)

# %%
# create empty beach dict
beach_data = {}

# loop through list of all titles found across all beaches
# and add an empty array to the beach data for each
for title in title_list:
    # need to break up the geo coordinates
    if title == "geo":
        beach_data["latitude"] = []
        beach_data["longitude"] = []
    else:
        beach_data[title] = []

# loop through all the beaches we scraped
for beach in r.json():
    # we only want cali data
    if beach["_source"]["state"] == "CA":
     
        for title in title_list:
            if title in beach["_source"]:
                if title == "geo":
                    # separate coordinates
                    beach_data["latitude"].append(beach["_source"][title][0])
                    beach_data["longitude"].append(beach["_source"][title][1])
                else:
                    # we have data in this field, add it to our array
                    beach_data[title].append(beach["_source"][title])
            else:
                # no data found for this column name --
                # set to null
                beach_data[title].append("")
        

#print(beach_data)
#print(len(beach_data))

# %%
# dump data into dataframe
beach_df = pd.DataFrame(beach_data)

# %%
# display dataframe
beach_df
# Out:
#        id                                              title  \
# 0    1044                               31502 Victoria Point
# 1      55                        Abalone Cove Shoreline Park
# 2     133             Alamitos Bay - 56th Place - on bayside
# 3     608        Alamitos Bay - Division Street and Bayshore
# 4     135                         Alamitos Bay - shore float
# ..    ...                                                ...
# 657    17  Will Rogers State Beach at Pulga Canyon storm ...
# 658    19  Will Rogers State Beach at Santa Monica Canyon...
# 659    18   Will Rogers State Beach at Temescal Canyon drain
# 660   321     Windansea Beach, projection of Playa Del Norte
# 661     4                     Zuma Beach at Zuma Creek mouth
#
#                        name1                              name2     name3  \
# 0
# 1               Abalone Cove                     Shoreline Park
# 2               Alamitos Bay                      at 56th Place   bayside
# 3               Alamitos Bay  between Division St. and Bayshore
# 4               Alamitos Bay                        shore float
# ..                       ...                                ...       ...
# 657  Will Rogers State Beach                       Pulga Canyon  at drain
# 658  Will Rogers State Beach                Santa Monica Canyon  at drain
# 659  Will Rogers State Beach                    Temescal Canyon  at drain
# 660          Windansea Beach      projection of Playa Del Norte
# 661               Zuma Beach                         Zume Creek
#
#                                            description notes  \
# 0    Single family residence sewage spill, 100 yard...
# 1    Abalone Cove is an 'open ocean' rocky beach lo...
# 2
# 3
# 4
# ..                                                 ...   ...
# 657  This site is at the wave wash of Pulga storm d...
# 658  This site is at the wave wash of Santa Monica ...
# 659  This site is at the wave wash of the Temescal ...
# 660
# 661  This monitoring site is at the mouth of Zuma C...
#
#              comments address                 city  ... dry_grade grade_note  \
# 0                                           Malibu  ...        ns
# 1             abalone          Rancho Palos Verdes  ...        A+
# 2          alamitos56                   Long Beach  ...         C
# 3    alamitosdivision                   Long Beach  ...        ns
# 4       alamitosfloat                   Long Beach  ...        A+
# ..                ...     ...                  ...  ...       ...        ...
# 657             pulga                  Los Angeles  ...        A+
# 658             smcyn             Pacific Palisade  ...        A+
# 659          temescal             Pacific Palisade  ...        A+
# 660     playadelnorte                     La Jolla  ...        A+
# 661              zuma                       Malibu  ...        A+
#
#     wet_grade             grade_created nowcast_pass_flag  \
# 0          ns  2015-05-04T00:00:00.000Z
# 1          A+  2021-04-02T00:00:00.000Z
# 2          ns  2020-04-10T00:00:00.000Z
# 3              2019-03-15T00:00:00.000Z
# 4           B  2021-04-02T00:00:00.000Z
# ..        ...                       ...               ...
# 657        A+  2021-04-02T00:00:00.000Z
# 658         A  2021-04-02T00:00:00.000Z                 1
# 659         F  2021-04-02T00:00:00.000Z                 1
# 660        ns  2021-04-02T00:00:00.000Z
# 661        ns  2021-04-02T00:00:00.000Z                 1
#
#                  nowcast_date  annual_summer_dry annual_year_wet  \
# 0    2018-07-04T05:00:00.000Z
# 1    2018-05-07T05:00:00.000Z
# 2                                              A               D
# 3
# 4    2020-08-26T05:00:00.000Z                  A               C
# ..                        ...                ...             ...
# 657
# 658  2020-11-01T05:00:00.000Z
# 659  2021-03-31T05:00:00.000Z
# 660                                           A+              ns
# 661  2019-10-31T05:00:00.000Z                  A              A+
#
#     annual_winter_dry annual_year
# 0
# 1
# 2                   A        2018
# 3
# 4                  A+        2018
# ..                ...         ...
# 657
# 658
# 659
# 660                ns        2018
# 661                 A        2018
#
# [662 rows x 38 columns]

# %%
# pull out columns of value
beach_df = beach_df[["id", "title", "name1", "latitude", "longitude", "address", "city", "state", "zip", "county", "active", "grade_updated","dry_grade", "wet_grade", "annual_summer_dry", "annual_year_wet", "annual_winter_dry", "annual_year", "grade_created"]]

# %%
beach_df
# Out:
#        id                                              title  \
# 0    1044                               31502 Victoria Point
# 1      55                        Abalone Cove Shoreline Park
# 2     133             Alamitos Bay - 56th Place - on bayside
# 3     608        Alamitos Bay - Division Street and Bayshore
# 4     135                         Alamitos Bay - shore float
# ..    ...                                                ...
# 657    17  Will Rogers State Beach at Pulga Canyon storm ...
# 658    19  Will Rogers State Beach at Santa Monica Canyon...
# 659    18   Will Rogers State Beach at Temescal Canyon drain
# 660   321     Windansea Beach, projection of Playa Del Norte
# 661     4                     Zuma Beach at Zuma Creek mouth
#
#                        name1            latitude             longitude  \
# 0                             34.035252000000000  -118.861320000000000
# 1               Abalone Cove  33.741585000000000  -118.379189000000000
# 2               Alamitos Bay  33.751183333000000  -118.125783333000000
# 3               Alamitos Bay  33.756313000000000  -118.131158000000000
# 4               Alamitos Bay  33.754166666000000  -118.130950000000000
# ..                       ...                 ...                   ...
# 657  Will Rogers State Beach  34.037545000000000  -118.542837000000000
# 658  Will Rogers State Beach  34.026854000000000  -118.520606000000000
# 659  Will Rogers State Beach  34.034713000000000  -118.536603000000000
# 660          Windansea Beach             32.8299             -117.2807
# 661               Zuma Beach  34.013671000000000  -118.821603000000000
#
#     address                 city                        county state    zip  \
# 0                         Malibu                   Los Angeles    CA  90265
# 1            Rancho Palos Verdes  Los Angeles -- LA Sanitation    CA  90275
# 2                     Long Beach     Los Angeles -- Long Beach    CA  90803
# 3                     Long Beach     Los Angeles -- Long Beach    CA  90803
# 4                     Long Beach     Los Angeles -- Long Beach    CA  90803
# ..      ...                  ...                           ...   ...    ...
# 657                  Los Angeles        Los Angeles -- LA City    CA  90272
# 658             Pacific Palisade        Los Angeles -- LA City    CA  90272
# 659             Pacific Palisade                   Los Angeles    CA  90272
# 660                     La Jolla                     San Diego    CA  92037
# 661                       Malibu                   Los Angeles    CA  90265
#
#                            county  active             grade_updated dry_grade  \
# 0                     Los Angeles   False  2018-07-04T12:39:31.100Z        ns
# 1    Los Angeles -- LA Sanitation    True  2021-04-02T00:00:00.000Z        A+
# 2       Los Angeles -- Long Beach    True  2020-04-10T00:00:00.000Z         C
# 3       Los Angeles -- Long Beach   False  2019-03-15T00:00:00.000Z        ns
# 4       Los Angeles -- Long Beach    True  2021-04-02T00:00:00.000Z        A+
# ..                            ...     ...                       ...       ...
# 657        Los Angeles -- LA City    True  2021-04-02T00:00:00.000Z        A+
# 658        Los Angeles -- LA City    True  2021-04-02T00:00:00.000Z        A+
# 659                   Los Angeles    True  2021-04-02T00:00:00.000Z        A+
# 660                     San Diego    True  2021-04-02T00:00:00.000Z        A+
# 661                   Los Angeles    True  2021-04-02T00:00:00.000Z        A+
#
#     wet_grade annual_summer_dry annual_year_wet annual_winter_dry annual_year  \
# 0          ns
# 1          A+
# 2          ns                 A               D                 A        2018
# 3
# 4           B                 A               C                A+        2018
# ..        ...               ...             ...               ...         ...
# 657        A+
# 658         A
# 659         F
# 660        ns                A+              ns                ns        2018
# 661        ns                 A              A+                 A        2018
#
#                 grade_created
# 0    2015-05-04T00:00:00.000Z
# 1    2021-04-02T00:00:00.000Z
# 2    2020-04-10T00:00:00.000Z
# 3    2019-03-15T00:00:00.000Z
# 4    2021-04-02T00:00:00.000Z
# ..                        ...
# 657  2021-04-02T00:00:00.000Z
# 658  2021-04-02T00:00:00.000Z
# 659  2021-04-02T00:00:00.000Z
# 660  2021-04-02T00:00:00.000Z
# 661  2021-04-02T00:00:00.000Z
#
# [662 rows x 20 columns]

# %%
# write dataframe to a CSV file
beach_df.to_csv("data/grade_info.csv")
